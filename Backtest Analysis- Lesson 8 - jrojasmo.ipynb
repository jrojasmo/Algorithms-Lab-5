# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5e93a82ff86f5d45c0ac1431')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:00:23|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-05</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-11-10</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>22</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>3.309%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>6.246%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>4.27%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.78</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.73</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.70</td>
#     </tr>
#     <tr>
# ...
